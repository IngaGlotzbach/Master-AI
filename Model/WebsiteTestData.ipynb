# %%
import numpy as np
import matplotlib.pyplot as plt
import os 
import cv2
import json
import pandas as pd
from pandas import read_csv

# %%
# 1. Wir müssen unsere Daten laden 
# 2. Daten prozessieren -> Daten alle kleinschreiben, und dann in Vektor umwandeln 
# 3. One hot encoding -> stellt bestimmten Wert als 1 der 0 dar

# %%
# 1. Daten laden
#import data and select rows 
data = pd.read_csv('testEinfach.csv', names = ['sessionId' , 'browser', 'clientId', 'clientX', 'clientY', 'date', 'element', 'siteName', 'timeStamp', 'type'])

X = data.iloc[:,1:12].values #die erste Reihe wird ausgelassen/ Spalten 
Y = data.iloc[:,9].values #alle Daten der Zeile 

# print(X[0][1])

# y = '30069bce4322'
# result = y.replace('-', '')
# y = float(result)

# X.astype('float32')
# Y.astype('float32')



DATADIRECTORY = "../cnn-test/TestsJSON"
CLASS_NAMES = ['TestEinfach', 'TestSchwer']

testEinfach = '../cnn-test/TestsJSON/TestEinfach/TestEinfach.json'
testSchwer = '../cnn-test/TestsJSON/TestSchwer/TestSchwer.json'

with open(testEinfach) as jsonEinfach:
    dataEinfach = json.load(jsonEinfach)

with open(testSchwer) as jsonSchwer:
    dataSchwer = json.load(jsonSchwer)

# %%
from sklearn.model_selection import train_test_split
 #split data into training and test sets
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
#feature scaling 
# from sklearn.preprocessing import StandardScaler

# sc = StandardScaler()
# x_train = sc.fit_transform(x_train)
# x_test = sc.fit_transform(x_test)

# %%
from sklearn import preprocessing
#es gehen anscheinend also wirklich nur float number
np.array(training)
normalize = preprocessing.normalize([training])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-f493d8c89fa0> in <module>
#       1 from sklearn import preprocessing
#       2 np.array(training)
# ----> 3 normalize = preprocessing.normalize([training])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in normalize(X, norm, axis, copy, return_norm)
#    1708         raise ValueError("'%d' is not a supported axis" % axis)
#    1709
# -> 1710     X = check_array(X, accept_sparse=sparse_format, copy=copy,
# ...

# %%
# 2. Daten normalisieren da es ja unterschiedliche Daten sind (unterschiedliche Größe Height, Width etc)

normalizedEinfach = pd.json_normalize(dataEinfach)
normalizedSchwer = pd.json_normalize(dataSchwer)

df = pd.concat([normalizedEinfach, normalizedSchwer])

# %%
training_data_einfach = []
training_data_schwer = []

for index in range(len(dataEinfach)):
    data_einfach = [0, dataEinfach[index]]
    training_data_einfach.append(data_einfach)

for index in range(len(dataSchwer)):
    data_schwer = [1, dataSchwer[index]]
    training_data_schwer.append(data_schwer)

print(training_data_einfach)


# training_data.append([CLASS_NAMES[0], normalizedEinfach])
# print(training_data.)

# def create_training_data():
#     for category in CATEGORIES:
#         path = os.path.join(DATADIR,category) #bringt uns zum path von Katze oder Hund (achsooo durch den ganzen Ordner dann)
#         class_num = CATEGORIES.index(category) #durch index setzen wir die Klasse 
#         for img in os.listdir(path):# gehen durch jedes Bild durch und machen es grau um Größe zu reduzieren 
#             try: 
#                 img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE) # in img_array sind alle unsere Tiere 
#                 new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
#                 training_data.append([new_array, class_num])   
#             except Exception as e: 
#                 pass

# create_training_data()
# bei binären Klassifikationsfällen möchte man dass die Anzahl der Daten recht ausgeglichen ist. Deshalb braucht man Weights für die jeweiligen Klassen
# Out:
# [[0, {'_id': {'$oid': '6329cdc0ac467df3f88b8b38'}, 'clientId': '30069bce-4322', 'elementId': 'inputPet', 'timeStamp': '1795.2999999998137', 'type': 'mouseover', 'siteName': 'TestEinfach', 'date': '2022-09-20T14:27:12.752Z', 'clientX': '452', 'clientY': '372'}], [0, {'_id': {'$oid': '6329cdc0ac467df3f88b8b39'}, 'clientId': '30069bce-4322', 'elementId': 'inputPet', 'timeStamp': '1859.8999999994412', 'type': 'mouseout', 'siteName': 'TestEinfach', 'date': '2022-09-20T14:27:12.811Z', 'clientX': '500', 'clientY': '335'}], [0, {'_id': {'$oid': '6329cdc1ac467df3f88b8b3a'}, 'clientId': '30069bce-4322', 'elementId': 'inputCountry', 'timeStamp': '2191.199999999255', 'type': 'mouseover', 'siteName': 'TestEinfach', 'date': '2022-09-20T14:27:13.144Z', 'clientX': '596', 'clientY': '267'}], [0, {'_id': {'$oid': '6329cdc1ac467df3f88b8b3b'}, 'clientId': '30069bce-4322', 'elementId': 'inputCountry', 'timeStamp': '2488.399999999441', 'type': 'focus', 'siteName': 'TestEinfach', 'date': '2022-09-20T14:27:
# ...

# %%
# 3. Shuffle the training_data damit man mehr Variation hat --> erst kommen Dogs und dann Cats 

df = df.sample(frac=1)
# Out:
#            clientId         elementId           timeStamp      type  \
# 542   b1438bb6-460f        inputRiver   33934.79999999702  mouseout
# 728   5d2b5f6e-c4fd        inputRiver   5068.100000008941  mouseout
# 70    5b56fbb0-acca            window                8109    scroll
# 553   b1438bb6-460f  inputTemperature               49367  mouseout
# 1034  3ef258d5-b25d            window  140396.00000000003    scroll
# ...             ...               ...                 ...       ...
# 669   0dc5b0e2-6acb  inputTemperature   19182.09999999404      blur
# 697   0dc5b0e2-6acb        nextButton   29779.79999999702     click
# 493   f56b7d5a-08f8            window  48913.700000000186    scroll
# 210   433e3c22-116d        inputRiver   99815.30000000075  mouseout
# 342   f56b7d5a-08f8            window  21412.400000000373    scroll
#
#          siteName                      date clientX clientY  \
# 542    TestSchwer  2022-09-23T10:40:48.962Z     632     736
# ...

# %%
X = [] #feature set
Y = [] #lables

# %%
for features, label in df: 
    X.append(features)
    Y.append(label)

#X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1) # -1 ist wie viele Features wir haben , 1 ist ein gray-scale !! important
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-066364157ee3> in <module>
# ----> 1 for features, label in df:
#       2     X.append(features)
#       3     Y.append(label)
#       4
#       5 #X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1) # -1 ist wie viele Features wir haben , 1 ist ein gray-scale !! important
#
# ValueError: too many values to unpack (expected 2)

# %%
import pickle

pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("Y.pickle", "wb")
pickle.dump(Y, pickle_out)
pickle_out.close()

# %%
pickle_in = open("X.pickle", "rb")
X = pickle.load(pickle_in)

# %%
X[1]
# Out:
# array([[[123],
#         [122],
#         [133],
#         ...,
#         [197],
#         [197],
#         [194]],
#
#        [[129],
#         [127],
#         [135],
#         ...,
#         [204],
#         [203],
#         [199]],
#
#        [[136],
#         [132],
#         [143],
#         ...,
#         [206],
#         [204],
#         [204]],
#
#        ...,
#
#        [[203],
#         [198],
#         [205],
#         ...,
#         [211],
#         [210],
#         [201]],
#
#        [[202],
#         [199],
#         [202],
#         ...,
#         [206],
#         [206],
#         [200]],
#
#        [[195],
#         [203],
#         [196],
#         ...,
#         [206],
#         [197],
#         [180]]], dtype=uint8)
